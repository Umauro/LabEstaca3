# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sci
from scipy import stats
import statsmodels.api as sm
#import warnings
#warnings.filterwarnings('ignore')

# %%
muestra1 = pd.read_csv('muestra1.csv')
plt.subplot(131)
sm.qqplot(muestra1['valor'], stats.exponweib, distargs=(40,15), line='q')
plt.subplot(132)
sm.qqplot(muestra1['valor'], stats.exponweib, distargs=(19,9), line='q')
plt.subplot(133)
sm.qqplot(muestra1['valor'], stats.exponweib, distargs=(10,20), line='q')
plt.subplot(231)
sm.qqplot(muestra1['valor'], stats.exponweib, distargs=(15,40), line='q')
plt.subplot(232)
sm.qqplot(muestra1['valor'], stats.exponweib, distargs=(30,25), line='q')
plt.subplot(233)
sm.qqplot(muestra1['valor'], stats.exponweib, distargs=(20,10), line='q')
plt.show()
